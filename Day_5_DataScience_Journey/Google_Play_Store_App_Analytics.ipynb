# %% [markdown]
# # Introduction
#
# In this notebook, we will do a comprehensive analysis of the Android app market by comparing thousands of apps in the Google Play store.

# %% [markdown]
# # About the Dataset of Google Play Store Apps & Reviews

# %% [markdown]
# **Data Source:** <br>
# App and review data was scraped from the Google Play Store by Lavanya Gupta in 2018. Original files listed [here](
# https://www.kaggle.com/lava18/google-play-store-apps).

# %% [markdown]
# # Import Statements

# %%
import pandas as pd
import plotly.express as px

# %% [markdown]
# # Notebook Presentation

# %%
# Show numeric output in decimal format e.g., 2.15
pd.options.display.float_format = '{:,.2f}'.format

# %% [markdown]
# # Read the Dataset

# %%
df_apps = pd.read_csv('apps.csv')

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# **Challenge**: How many rows and columns does `df_apps` have? What are the column names? Look at a random sample of 5 different rows with [.sample()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.sample.html).

# %%
print(df_apps.shape)
print(df_apps.columns)
df_apps.head()
# Out:
# (10841, 12)
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size_MBs', 'Installs', 'Type',
#        'Price', 'Content_Rating', 'Genres', 'Last_Updated', 'Android_Ver'],
#       dtype='object')
#                                             App         Category  Rating  \
# 0                       Ak Parti Yardım Toplama           SOCIAL     NaN
# 1                    Ain Arabic Kids Alif Ba ta           FAMILY     NaN
# 2  Popsicle Launcher for Android P 9.0 launcher  PERSONALIZATION     NaN
# 3                     Command & Conquer: Rivals           FAMILY     NaN
# 4                                    CX Network         BUSINESS     NaN
#
#    Reviews  Size_MBs Installs  Type   Price Content_Rating           Genres  \
# 0        0      8.70        0  Paid  $13.99           Teen           Social
# 1        0     33.00        0  Paid   $2.99       Everyone        Education
# 2        0      5.50        0  Paid   $1.49       Everyone  Personalization
# ...

# %%
df_apps.describe()
# Out:
#         Rating       Reviews  Size_MBs
# count 9,367.00     10,841.00 10,841.00
# mean      4.19    444,111.93     19.77
# std       0.52  2,927,628.66     21.40
# min       1.00          0.00      0.01
# 25%       4.00         38.00      4.90
# 50%       4.30      2,094.00     11.00
# 75%       4.50     54,768.00     27.00
# max       5.00 78,158,306.00    100.00

# %%
df_apps.sample(5) #x random samples from the table
# Out:
#                                 App       Category  Rating  Reviews  Size_MBs  \
# 945          420 BZ Budeze Delivery        MEDICAL    5.00        2     11.00
# 4458  Analog and Digital Clock AW-7          TOOLS    4.00      202      2.90
# 3475                  Deaf World DW  COMMUNICATION    4.30      298      3.50
# 7944                  Skip-Bo™ Free           GAME    3.50    46801     60.00
# 5368                   C-SPAN Radio         FAMILY    3.60      608      5.40
#
#        Installs  Type Price Content_Rating         Genres       Last_Updated  \
# 945         100  Free     0     Mature 17+        Medical       June 6, 2018
# 4458     50,000  Free     0       Everyone          Tools     March 15, 2018
# 3475     10,000  Free     0           Teen  Communication  November 28, 2017
# 7944  1,000,000  Free     0       Everyone           Card     August 3, 2018
# 5368    100,000  Free     0       Everyone  Entertainment       May 17, 2018
#
#      Android_Ver
# ...

# %% [markdown]
# ### Drop Unused Columns
#
# **Challenge**: Remove the columns called `Last_Updated` and `Android_Version` from the DataFrame. We will not use these columns.

# %%
# df_apps.drop(['Last_Updated','Android_Ver'],axis=1,inplace=True)
df_apps.head()
# Out:
#                                             App         Category  Rating  \
# 0                       Ak Parti Yardım Toplama           SOCIAL     NaN
# 1                    Ain Arabic Kids Alif Ba ta           FAMILY     NaN
# 2  Popsicle Launcher for Android P 9.0 launcher  PERSONALIZATION     NaN
# 3                     Command & Conquer: Rivals           FAMILY     NaN
# 4                                    CX Network         BUSINESS     NaN
#
#    Reviews  Size_MBs Installs  Type   Price Content_Rating           Genres  \
# 0        0      8.70        0  Paid  $13.99           Teen           Social
# 1        0     33.00        0  Paid   $2.99       Everyone        Education
# 2        0      5.50        0  Paid   $1.49       Everyone  Personalization
# 3        0     19.00        0   NaN       0   Everyone 10+         Strategy
# 4        0     10.00        0  Free       0       Everyone         Business
#
#      Last_Updated         Android_Ver
# ...

# %% [markdown]
# ### Find and Remove NaN values in Ratings
#
# **Challenge**: How may rows have a NaN value (not-a-number) in the Ratings column? Create DataFrame called `df_apps_clean` that does not include these rows.

# %%
df_apps.isna().values.sum()
clean_df=df_apps.dropna()

# %%
clean_df.sample(5)
# clean_df.shape (9367, 10)
# Out:
#                                  App Category  Rating  Reviews  Size_MBs  \
# 8548                         Mahjong   FAMILY    4.50    33983     22.00
# 8553                          DS get    TOOLS    3.40    71852     22.00
# 10010  Terminal Emulator for Android    TOOLS    4.40   113951      0.54
# 9753                  Bomber Friends     GAME    4.50   776730     49.00
# 3404      Skill Tree - BL Pre Sequel   FAMILY    4.30      855      7.00
#
#          Installs  Type Price Content_Rating              Genres  \
# 8548    5,000,000  Free     0       Everyone  Puzzle;Brain Games
# 8553    5,000,000  Free     0       Everyone               Tools
# 10010  10,000,000  Free     0       Everyone               Tools
# 9753   10,000,000  Free     0   Everyone 10+              Action
# 3404       10,000  Free     0           Teen       Entertainment
#
#             Last_Updated   Android_Ver
# 8548      August 2, 2018  4.0.3 and up
# 8553        May 23, 2018    4.1 and up
# ...

# %% [markdown]
# ### Find and Remove Duplicates
#
# **Challenge**: Are there any duplicates in data? Check for duplicates using the [.duplicated()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.duplicated.html) function. How many entries can you find for the "Instagram" app? Use [.drop_duplicates()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.drop_duplicates.html) to remove any duplicates from `df_apps_clean`.

# %%
clean_df.duplicated()
# Out:
# 21       False
# 28       False
# 47       False
# 82       False
# 99       False
#          ...
# 10836    False
# 10837    False
# 10838    False
# 10839     True
# 10840    False
# Length: 9365, dtype: bool

# %%
clean_df[clean_df['App']=='Instagram'].duplicated(keep='first') #subset=['App','Type','Price'] or it will return 1 DUPLICATE INSTED OF 3
# Out:
# 10806    False
# 10808    False
# 10809     True
# 10810    False
# dtype: bool

# %%
clean_df_no_dup=clean_df.drop_duplicates(subset=['App','Type','Price'])

# %%
clean_df_no_dup.shape
# Out:
# (8197, 12)

# %%
clean_df_no_dup[clean_df_no_dup['App']=='Instagram']
# Out:
#              App Category  Rating   Reviews  Size_MBs       Installs  Type  \
# 10806  Instagram   SOCIAL    4.50  66577313      5.30  1,000,000,000  Free
#
#       Price Content_Rating  Genres   Last_Updated         Android_Ver
# 10806     0           Teen  Social  July 31, 2018  Varies with device

# %% [markdown]
# # Find Highest Rated Apps
#
# **Challenge**: Identify which apps are the highest rated. What problem might you encounter if you rely exclusively on ratings alone to determine the quality of an app?
#
# PROBLEM: LOW REVIEWS AND INSTALLATIONS

# %%
df=clean_df_no_dup
id=df.Rating.idxmax()
df.loc[id]
# Out:
# App               KBA-EZ Health Guide
# Category                      MEDICAL
# Rating                           5.00
# Reviews                             4
# Size_MBs                        25.00
# Installs                            1
# Type                             Free
# Price                               0
# Content_Rating               Everyone
# Genres                        Medical
# Last_Updated           August 2, 2018
# Android_Ver              4.0.3 and up
# Name: 21, dtype: object

# %% [markdown]
# # Find 5 Largest Apps in terms of Size (MBs)
#
# **Challenge**: What's the size in megabytes (MB) of the largest Android apps in the Google Play Store. Based on the data, do you think there could be limit in place or can developers make apps as large as they please?

# %%
df.sort_values(by='Size_MBs',ascending=False).head(10)
# Out:
#                                                     App            Category  \
# 9942                     Talking Babsy Baby: Baby Games           LIFESTYLE
# 10687                            Hungry Shark Evolution                GAME
# 9943                              Miami crime simulator                GAME
# 9944                       Gangster Town: Vice District              FAMILY
# 3144                                         Vi Trainer  HEALTH_AND_FITNESS
# 9945                                    Ultimate Tennis              SPORTS
# 7926                                          Post Bank             FINANCE
# 7927                        The Walking Dead: Our World                GAME
# 7928                      Stickman Legends: Shadow Wars                GAME
# 4176   Car Crash III Beam DH Real Damage Simulator 2018                GAME
#
#        Rating  Reviews  Size_MBs     Installs  Type  Price Content_Rating  \
# ...

# %% [markdown]
# # Find the 5 App with Most Reviews
#
# **Challenge**: Which apps have the highest number of reviews? Are there any paid apps among the top 50?
#
#
#  **Only_free**

# %%
df.sort_values(by='Reviews',ascending=False).head(10)
# Out:
#                                                      App       Category  \
# 10805                                           Facebook         SOCIAL
# 10785                                 WhatsApp Messenger  COMMUNICATION
# 10806                                          Instagram         SOCIAL
# 10784           Messenger – Text and Video Chat for Free  COMMUNICATION
# 10650                                     Clash of Clans           GAME
# 10744            Clean Master- Space Cleaner & Antivirus          TOOLS
# 10835                                     Subway Surfers           GAME
# 10828                                            YouTube  VIDEO_PLAYERS
# 10746  Security Master - Antivirus, VPN, AppLock, Boo...          TOOLS
# 10584                                       Clash Royale           GAME
#
#        Rating   Reviews  Size_MBs       Installs  Type Price Content_Rating  \
# 10805    4.10  78158306      5.30  1,000,000,000  Free     0           Teen
# ...

# %% [markdown]
# # Plotly Pie and Donut Charts - Visualise Categorical Data: Content Ratings

# %%
content_rating=df.Content_Rating.value_counts()
content_rating
# Out:
# Everyone           6619
# Teen                912
# Mature 17+          357
# Everyone 10+        305
# Adults only 18+       3
# Unrated               1
# Name: Content_Rating, dtype: int64

# %% [markdown]
# If you’d like to configure other aspects of the chart, that you can’t see in the list of parameters, you can call a method called **.update_traces()**. In plotly lingo, “traces” refer to graphical marks on a figure. Think of “traces” as collections of attributes. Here we update the traces to change how the text is displayed.

# %%
fig=px.pie(labels=content_rating.index,
           values=content_rating.values,
           names = content_rating.index,
           title='Range by age',
           hole=0.4)
fig.update_traces(textposition='outside', textinfo='percent+label')
#
fig.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/plotly/express/_core.py:137: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   return args["labels"][column]
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#hole=0.X stays for DONUT in px.pie(
#    smth= '  ',
# )

# %% [markdown]
# # Numeric Type Conversion: Examine the Number of Installs
#
# **Challenge**: How many apps had over 1 billion (that's right - BILLION) installations? How many apps just had a single install?
#
# Check the datatype of the Installs column.
#
# Count the number of apps at each level of installations.
#
# Convert the number of installations (the Installs column) to a numeric data type. Hint: this is a 2-step process. You'll have make sure you remove non-numeric characters first.

# %%
df.Installs.describe()
# Out:
# count          8197
# unique           19
# top       1,000,000
# freq           1417
# Name: Installs, dtype: object

# %%
df.Installs.value_counts()
# Out:
# 1,000,000        1417
# 100,000          1096
# 10,000            987
# 10,000,000        933
# 1,000             697
# 5,000,000         607
# 500,000           504
# 50,000            457
# 5,000             425
# 100               303
# 50,000,000        202
# 500               199
# 100,000,000       189
# 10                 69
# 50                 56
# 500,000,000        24
# 1,000,000,000      20
# 5                   9
# 1                   3
# Name: Installs, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8197 entries, 21 to 10835
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             8197 non-null   object
#  1   Category        8197 non-null   object
#  2   Rating          8197 non-null   float64
#  3   Reviews         8197 non-null   int64
#  4   Size_MBs        8197 non-null   float64
#  5   Installs        8197 non-null   object
#  6   Type            8197 non-null   object
#  7   Price           8197 non-null   object
#  8   Content_Rating  8197 non-null   object
#  9   Genres          8197 non-null   object
#  10  Last_Updated    8197 non-null   object
#  11  Android_Ver     8197 non-null   object
# dtypes: float64(2), int64(1), object(9)
# memory usage: 1.1+ MB

# %%
df.Installs=df.Installs.astype(str).str.replace(',','')
#REPLACE , on empty string
# Out:
# <ipython-input-25-927024fb8911>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df.Installs=pd.to_numeric(df.Installs)
#CHANGE OBJECT TYPE to numeric(int)
# Out:
# <ipython-input-26-ba8bcd5fe095>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df.Installs.value_counts()
# Out:
# 1000000       1417
# 100000        1096
# 10000          987
# 10000000       933
# 1000           697
# 5000000        607
# 500000         504
# 50000          457
# 5000           425
# 100            303
# 50000000       202
# 500            199
# 100000000      189
# 10              69
# 50              56
# 500000000       24
# 1000000000      20
# 5                9
# 1                3
# Name: Installs, dtype: int64

# %% [markdown]
# # Find the Most Expensive Apps, Filter out the Junk, and Calculate a (ballpark) Sales Revenue Estimate
#
# Let's examine the Price column more closely.
#
# **Challenge**: Convert the price column to numeric data. Then investigate the top 20 most expensive apps in the dataset.
#
# Remove all apps that cost more than $250 from the `df_apps_clean` DataFrame.
#
# Add a column called 'Revenue_Estimate' to the DataFrame. This column should hold the price of the app times the number of installs. What are the top 10 highest grossing paid apps according to this estimate? Out of the top 10 highest grossing paid apps, how many are games?

# %%
df.Price=df.Price.astype(str).str.replace('$','')
# Out:
# <ipython-input-28-dbcf58177cae>:1: FutureWarning:
#
# The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#
# <ipython-input-28-dbcf58177cae>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df.Price=pd.to_numeric(df.Price)
df.Price.info()
# Out:
# <class 'pandas.core.series.Series'>
# Int64Index: 8197 entries, 21 to 10835
# Series name: Price
# Non-Null Count  Dtype
# --------------  -----
# 8197 non-null   float64
# dtypes: float64(1)
# memory usage: 386.1 KB
# <ipython-input-32-59bc209b4e22>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df.sort_values(by='Price',ascending=False).head(15)
# Out:
#                                   App             Category  Rating  Reviews  \
# 5633  Baldur's Gate: Enhanced Edition               FAMILY    4.50    20101
# 5438    CHRONO TRIGGER (Upgrade Ver.)               FAMILY    3.80    11250
# 3240                     ASCCP Mobile              MEDICAL    4.50       63
# 1023   500 AP World History Questions               FAMILY    4.70        7
# 1828            InfantRisk Center HCP              MEDICAL    2.60       41
# 1037      Jeppesen CR Flight Computer  MAPS_AND_NAVIGATION    3.30        3
# 5148               Star Wars ™: DIRTY                 GAME    4.50    38207
# 1812          Diabetes & Diet Tracker              MEDICAL    4.60      395
# 4865              XCOM®: Enemy Within               FAMILY    4.20    13752
# 3604                     BIG Launcher      PERSONALIZATION    4.30      881
# 2156                        Pocket AC          PHOTOGRAPHY    4.80      130
# ...

# %% [markdown]
# ### The most expensive apps sub $250

# %%
df=df[df.Price < 250]
df.sort_values('Price',ascending=False).head(10)
# Out:
#                                                     App   Category  Rating  \
# 2281                          Vargo Anesthesia Mega App    MEDICAL    4.60
# 1407                                       LTC AS Legal    MEDICAL    4.00
# 2629                                   I am Rich Person  LIFESTYLE    4.20
# 2481                            A Manual of Acupuncture    MEDICAL    3.50
# 4264                            Golfshot Plus: Golf GPS     SPORTS    4.10
# 504                           AP Art History Flashcards     FAMILY    5.00
# 2463                                 PTA Content Master    MEDICAL    4.20
# 2207                                           EMT PASS    MEDICAL    3.40
# 3241  Muscle Premium - Human Anatomy, Kinesiology, B...    MEDICAL    4.20
# 4772   Human Anatomy Atlas 2018: Complete 3D Human Body    MEDICAL    4.50
#
#       Reviews  Size_MBs  Installs  Type  Price Content_Rating     Genres  \
# ...

# %% [markdown]
# ### Highest Grossing Paid Apps (ballpark estimate)

# %%
df['Revenue_Estimate']=df.Price.mul(df.Installs)
# Out:
# <ipython-input-34-87b0245c93be>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df.sort_values('Revenue_Estimate',ascending=False).head(50)
# Out:
#                                                     App             Category  \
# 9220                                          Minecraft               FAMILY
# 8825                                      Hitman Sniper                 GAME
# 7151                      Grand Theft Auto: San Andreas                 GAME
# 7977                            Sleep as Android Unlock            LIFESTYLE
# 7477                                Facetune - For Free          PHOTOGRAPHY
# 6594                                DraStic DS Emulator                 GAME
# 6082                                       Weather Live              WEATHER
# 7044                                             Tasker                TOOLS
# 7954                                        Bloons TD 5               FAMILY
# 6746                         Card Wars - Adventure Time               FAMILY
# 7633                            Five Nights at Freddy's                 GAME
# ...

# %% [markdown]
# # Plotly Bar Charts & Scatter Plots: Analysing App Categories

# %%
df.Category.nunique()
# Out:
# 33

# %%
top_10_cat=df.Category.value_counts()[:10]

# %% [markdown]
# ### Vertical Bar Chart - Highest Competition (Number of Apps)

# %%
fig=px.bar(
    x=top_10_cat.index,
    y=top_10_cat.values
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### Horizontal Bar Chart - Most Popular Categories (Highest Downloads)

# %%
category_installs=df.groupby('Category').agg(
    {'Installs': pd.Series.sum}
)

# %%
high_cat_int=category_installs.sort_values('Installs',ascending=True)
high_cat_int.tail(10)
# Out:
#                        Installs
# Category
# NEWS_AND_MAGAZINES   2369110650
# TRAVEL_AND_LOCAL     2894859300
# VIDEO_PLAYERS        3916897200
# FAMILY               4437554490
# PHOTOGRAPHY          4649143130
# SOCIAL               5487841475
# PRODUCTIVITY         5788070180
# TOOLS                8099724500
# COMMUNICATION       11039241530
# GAME                13858762717

# %%
h_bar=px.bar(
      x=high_cat_int.Installs,
      y=high_cat_int.index,
      orientation='h',
      title='Category Popularity'

)

h_bar.update_layout(xaxis_title='Number of Downloads', yaxis_title='Category')

h_bar.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### Category Concentration - Downloads vs. Competition
#
# **Challenge**:
# * First, create a DataFrame that has the number of apps in one column and the number of installs in another:
#
# <img src=https://imgur.com/uQRSlXi.png width="350">
#
# * Then use the [plotly express examples from the documentation](https://plotly.com/python/line-and-scatter/) alongside the [.scatter() API reference](https://plotly.com/python-api-reference/generated/plotly.express.scatter.html)to create scatter plot that looks like this.
#
# <img src=https://imgur.com/cHsqh6a.png>
#
# *Hint*: Use the size, hover_name and color parameters in .scatter(). To scale the yaxis, call .update_layout() and specify that the yaxis should be on a log-scale like so: yaxis=dict(type='log')

# %%
concentration=df.groupby('Category').agg(
    {
        'Installs': pd.Series.sum,
        'App':pd.Series.count

    }
)

# %%
concentration.shape
high_conc=concentration.sort_values(by='App')
high_conc.head()
# Out:
#                  Installs  App
# Category
# BEAUTY           26916200   42
# EVENTS           15949410   45
# PARENTING        31116110   50
# COMICS           44931100   54
# ART_AND_DESIGN  114233100   61

# %%
scatter=px.scatter(
    x=high_conc.App,
    y=high_conc.Installs,
    title="Category Concentration",
    size=high_conc.App, #SIZE OF DOTS
    hover_name=high_conc.index,
    color=high_conc.Installs #COLOR DEPEND OS INSTALLS

)
scatter.update_layout(xaxis_title="Number of Apps(Lower=More Concentrated)",yaxis_title='Installs',yaxis=dict(type='log'))
scatter.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # Extracting Nested Data from a Column
#
# **Challenge**: How many different types of genres are there? Can an app belong to more than one genre? Check what happens when you use .value_counts() on a column with nested values? See if you can work around this problem by using the .split() function and the DataFrame's [.stack() method](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.stack.html).

# %%
df.Genres.head(10)
genres=df.value_counts('Genres')
genres.sort_values(ascending=True).head(50)
# Out:
# Genres
# Comics;Creativity                        1
# Travel & Local;Action & Adventure        1
# Strategy;Creativity                      1
# Communication;Creativity                 1
# Tools;Education                          1
# Adventure;Brain Games                    1
# Arcade;Pretend Play                      1
# Adventure;Education                      1
# Strategy;Education                       1
# Card;Brain Games                         1
# Art & Design;Pretend Play                1
# Parenting;Brain Games                    1
# Casual;Music & Video                     1
# Music & Audio;Music & Video              1
# Lifestyle;Pretend Play                   1
# Board;Pretend Play                       1
# Lifestyle;Education                      1
# Entertainment;Education                  1
# Health & Fitness;Education               1
# Racing;Pretend Play                      1
# Health & Fitness;Action & Adventure      1
# Role Playing;Brain Games                 1
# ...

# %%
# new_df=df.Genres.str.split(';', expand=True)
stack=df.Genres.str.split(';',expand=True).stack()

# %%
stack.sample(5)
# Out:
# 10021  0            Tools
# 5861   0       Simulation
# 2865   0         Business
# 21     0          Medical
# 3754   0    Entertainment
# dtype: object

# %%
# new_df.value_counts("Genres").sort_values()
num=stack.value_counts()
# print(len(num))
# stack.head()
num.head(50)
# Out:
# Tools                      719
# Education                  587
# Entertainment              498
# Action                     304
# Productivity               301
# Lifestyle                  298
# Personalization            296
# Finance                    296
# Medical                    292
# Sports                     270
# Photography                263
# Business                   262
# Communication              258
# Health & Fitness           245
# Casual                     216
# News & Magazines           204
# Social                     203
# Simulation                 200
# Travel & Local             187
# Arcade                     185
# Shopping                   180
# Books & Reference          171
# Video Players & Editors    150
# Dating                     134
# Puzzle                     124
# Maps & Navigation          118
# Role Playing               111
# Racing                     103
# Action & Adventure          96
# Strategy                    95
# ...

# %% [markdown]
# # Colour Scales in Plotly Charts - Competition in Genres

# %% [markdown]
# **Challenge**: Can you create this chart with the Series containing the genre data?
#
# <img src=https://imgur.com/DbcoQli.png width=400>
#
# Try experimenting with the built in colour scales in Plotly. You can find a full list [here](https://plotly.com/python/builtin-colorscales/).
#
# * Find a way to set the colour scale using the color_continuous_scale parameter.
# * Find a way to make the color axis disappear by using coloraxis_showscale.

# %%
bars=px.bar(
    x=num.index[:15],
    y=num.values[:15],
    title='Top Genres',
    hover_name=num.index[:15],
    color=num.values[:15],
   color_continuous_scale='Agsunset'
)
bars.update_layout(xaxis_title="Genre",yaxis_title='Number of apps',yaxis=dict(type='log'),
                   coloraxis_showscale=False)
bars.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # Grouped Bar Charts: Free vs. Paid Apps per Category

# %%
dff=df.groupby('Price').count()
test=df.groupby('Category').agg({
    'Price': pd.Series.count,
    'App': pd.Series.count
})
test

# %% [markdown]
# **Challenge**: Use the plotly express bar [chart examples](https://plotly.com/python/bar-charts/#bar-chart-with-sorted-or-ordered-categories) and the [.bar() API reference](https://plotly.com/python-api-reference/generated/plotly.express.bar.html#plotly.express.bar) to create this bar chart:
#
# <img src=https://imgur.com/LE0XCxA.png>
#
# You'll want to use the `df_free_vs_paid` DataFrame that you created above that has the total number of free and paid apps per category.
#
# See if you can figure out how to get the look above by changing the `categoryorder` to 'total descending' as outlined in the documentation here [here](https://plotly.com/python/categorical-axes/#automatically-sorting-categories-by-name-or-total-value).

# %%
condition1=df['Price']==0
free=df[condition1].value_counts('Category')

paid=df[df.Price!=0].value_counts('Category')

# %%
free.head(
    3
)
# Out:
# Category
# FAMILY    1456
# GAME       834
# TOOLS      656
# dtype: int64

# %%
comparison=px.bar(
    x=free.index,
    y=free.values,
)
comparison.update_layout(xaxis_title='Category',yaxis_title='Number of Apps')
comparison.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
gr_df=df.groupby(['Category','Type'],as_index=False).agg({
    'App': pd.Series.count
})
gr_df.head(3)
# Out:
#             Category  Type  App
# 0     ART_AND_DESIGN  Free   58
# 1     ART_AND_DESIGN  Paid    3
# 2  AUTO_AND_VEHICLES  Free   72

# %%
group_bar=px.bar(gr_df,
    x='Category',
    y='App',
    barmode='group',
    title='Free vs Paid Apps by Category',
                 color='Type',

)
group_bar.update_layout(xaxis_title='Category',
                    yaxis_title='Number of Apps',
                    xaxis={'categoryorder':'total descending'},
                    yaxis=dict(type='log'))
group_bar.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # Plotly Box Plots: Lost Downloads for Paid Apps
#
# **Challenge**: Create a box plot that shows the number of Installs for free versus paid apps. How does the median number of installations compare? Is the difference large or small?
#
# Use the [Box Plots Guide](https://plotly.com/python/box-plots/) and the [.box API reference](https://plotly.com/python-api-reference/generated/plotly.express.box.html) to create the following chart.
#
# <img src=https://imgur.com/uVsECT3.png>

# %%
new_df=df.groupby('Category').agg({
    'Installs': pd.Series.sum
}
)
new_df.sort_values(by='Installs',ascending=False)
# Out:
#                         Installs
# Category
# GAME                 13858762717
# COMMUNICATION        11039241530
# TOOLS                 8099724500
# PRODUCTIVITY          5788070180
# SOCIAL                5487841475
# PHOTOGRAPHY           4649143130
# FAMILY                4437554490
# VIDEO_PLAYERS         3916897200
# TRAVEL_AND_LOCAL      2894859300
# NEWS_AND_MAGAZINES    2369110650
# ENTERTAINMENT         2113660000
# BOOKS_AND_REFERENCE   1665791655
# PERSONALIZATION       1532341930
# SHOPPING              1400331540
# HEALTH_AND_FITNESS    1134006220
# SPORTS                1096431465
# BUSINESS               692018120
# LIFESTYLE              503611120
# MAPS_AND_NAVIGATION    503267560
# FINANCE                455249400
# WEATHER                361096500
# EDUCATION              352852000
# FOOD_AND_DRINK         211677750
# DATING                 140912410
# ART_AND_DESIGN         114233100
# HOUSE_AND_HOME          97082000
# AUTO_AND_VEHICLES       53129800
# ...

# %%
box1=px.box(new_df,
           y='Installs')
box1.update_layout(yaxis=dict(type='log'))
box1.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df.head(3)
# Out:
#                     App Category  Rating  Reviews  Size_MBs  Installs  Type  \
# 21  KBA-EZ Health Guide  MEDICAL    5.00        4     25.00         1  Free
# 28             Ra Ga Ba     GAME    5.00        2     20.00         1  Paid
# 47              Mu.F.O.     GAME    5.00        2     16.00         1  Paid
#
#     Price Content_Rating   Genres      Last_Updated   Android_Ver  \
# 21   0.00       Everyone  Medical    August 2, 2018  4.0.3 and up
# 28   1.49       Everyone   Arcade  February 8, 2017    2.3 and up
# 47   0.99       Everyone   Arcade     March 3, 2017    2.3 and up
#
#     Revenue_Estimate
# 21              0.00
# 28              1.49
# 47              0.99

# %%
box = px.box(df,
             y='Installs',
             x='Type',
             color='Type',
             notched=True,
             points='all',
             title='How Many Downloads are Paid Apps Giving Up?')

box.update_layout(yaxis=dict(type='log'))

box.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # Plotly Box Plots: Revenue by App Category
#
# **Challenge**: See if you can generate the chart below:
#
# <img src=https://imgur.com/v4CiNqX.png>
#
# Looking at the hover text, how much does the median app earn in the Tools category? If developing an Android app costs $30,000 or thereabouts, does the average photography app recoup its development costs?
#
# Hint: I've used 'min ascending' to sort the categories.

# %%
paid_apps=df[df['Type']=='Paid']
# paid_apps.groupby('Category').sum()
last_box=px.box(paid_apps,
                x='Category',
                y='Revenue_Estimate',)
last_box.update_layout(xaxis={'categoryorder':'min ascending'},
                       yaxis=dict(type='log'))

last_box.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # How Much Can You Charge? Examine Paid App Pricing Strategies by Category
#
# **Challenge**: What is the median price price for a paid app? Then compare pricing by category by creating another box plot. But this time examine the prices (instead of the revenue estimates) of the paid apps. I recommend using `{categoryorder':'max descending'}` to sort the categories.
